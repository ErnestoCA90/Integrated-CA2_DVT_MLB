# %%
from IPython.display import Image
Image("Cover Sheet.png")

# %% [markdown]
# # Introduction
#
# Presented that most of our time is spent in a work environment, job satisfaction is a vital component of peoples' lives. This aspect significantly affects the employees motivation, emotional well-being, and productivity. Additionally, employee retention and organizational productivity are strongly correlated with job satisfaction.
#
# The significance of job satisfaction stems from its ability to affect people's quality of life. When employees are happy with their jobs, they tend to expoerience more general happiness and well-being. On the other hand, a lack of job satisfaction can lead to stress, demotivation and adverse effects on people's physical and mental health.
# Numerous factors might have an impact on a person's level of job satisfaction. Some of these factor could be the work environment, pay an benefits, professional development and more. Balance between work and personal life, as well as recognition and valuation, among other things.
#
# Organisations atre better able to improve employee satisfaction and foster a positive work environment when they understand and analyse the factors that affect it. The use of data analysis techniques and automatic learning models can provide useful information for identifiying patterns and trends in employee data, allowing for the development of more effective employee satisfaction and productivity improvements strategies.
#
# This report will discuss how to analyse data collected from an organization in order to predict the employee's level of job satisfaction. To find relationships ans trends in the data that could be used to improve employee satisfaction and productivity , data preparation techniques, statistical analysis, and automatic learning models will be used.

# %% [markdown]
# # Business Understandig
#
# We are working to develop a machine learning model that can forecast an individual's level of job satisfaction. The following data is gathered from a company under the pretence of finding patterns and trends that could raise productivity and employee satisfaction, improve cision-making, develop effective personnel managment strategies and foster a more positive work environment. Their employees' information is included in the data set.

# %% [markdown]
# # Business Description

# %% [markdown]
# ### Research Question
#
# Can we determine a person's level of satisfaction while taking into account many characteristics connected to their current work?
#
# ### General Goal
#
# The main goal of this analysis is to predict the satisfaction level to use these insights to make job strategies and advise actions to encourage higher levels of job satisfaction which may result in greater retention of staff members to improve the productivity and the capacity to work better. Based on the aim we need to create a supervised ML clasificasion model since our variable target is discrete variable.
#
# ### Success criteria/indicators
#
# After applying our Machine Learning model using distinc methods and techniques to get our data we have achived our best accuracy from the Logistic Regresion Model. This outcome is the result of an iterative data preprocessing, characteristic selection, hyperparameter adjustment, and model validation.

# %% [markdown]
# # Technologies Used
#
# ### Model and machine learning algorithms
#
# the next study was analised using the Logistic regression model since is frequently employed for classification results.
#
# ### Libraries
#
# Many libraries have been used to perfomr various taks and model algorithms as. They migh consist of Pandas, Numpy, Seaborn, Matplotlib, Spicy, Statistics, PCA, LDA, etc.

# %% [markdown]
# # Accomplishment Data
#
# The dataset **Integrated_CA2_Dataset** describes some factors that could help or affect the satisfaction level. We have some attibutes to analyze and the dataset is composed of 1470 rows and 35 features from wich 9 are categorical and 26 numerical. We can take a look in the Data Dictionary to explore each one of them.
#
# ### Attributes
#
# The data is composed of 35 features, as we already indicated. Our dependent variable or the degree of job happines we will experience, is called **JobSatisfaction**. We will conduct independent analyses of each independently.
#
# ### Dimensions
#
# The shape of our data is 1470 rows and 35 columns as variables

# %% [markdown]
# # Data Understanding

# %% [markdown]
# **Target Variable:** JobSatisfaction
#
# **Predictors:**	Age: Attrition: BusinessTravel: DailyRate: Department: DistanceFromHome: Education: EducationField: EmployeeCount: EmployeeNumber: EnvironmentSatisfaction: Gender: HourlyRate: JobInvolvement: JobLevel: JobRole: MaritalStatus: MonthlyIncome: MonthlyRate: NumCompaniesWorked: Over18: OverTime: PercentSalaryHike: PerformanceRating: RelationshipSatisfaction: StandardHours: StockOptionLevel: TotalWorkingYears: TrainingTimesLastYear: WorkLifeBalance: YearsAtCompany: YearsInCurrentRole: YearsSinceLastPromotion: YearsWithCurrManager:
#
#     JobSatisfaction=1
#     JobSatisfaction=2
#     JobSatisfaction=3
#     JobSatisfaction=4

# %% [markdown]
# ### Data dictionary
#
# 1. Age: Indicates whether an employee has left the company
# 2. Attrition: Indicates whether an employee has left the company
# 3. BusinessTravel: The frequency of employee business trips
# 4. DailyRate: Daily employee payment rate
# 5. Department: The department in which the employe is employed
# 6. DistanceFromHome: The distance between the employee's home and the place of employment
# 7. Education: Education level of the employee
# 8. EducationField: The employee's study/training area
# 9. EmployeeCount: Number of employees
# 10. EmployeeNumber: The employee's identification number
# 11. EnvironmentSatisfaction: Employee level of satisfaction with work environment
# 12. Gender: Gender of the employee
# 13. HourlyRate: The employee's hourly rate
# 14. JobInvolvement: The employee's level of involvement in their work
# 15. JobLevel: The employee's level of position
# 16. JobRole: The employee's job title or position
# 17. JobSatisfaction: The employee's level of satisfaction with their job
# 18. MaritalStatus: The employee's civil status
# 20. MonthlyIncome: The employee's monthly pay
# 21. MonthlyRate: The employee's monthly wage
# 22. NumCompaniesWorked: Number of companies that the employee has previously worked for
# 23. Over18: Indicates whether the employee is older than 18 years old
# 24. OverTime: Indicate whether the employee works overtime
# 25. PercentSalaryHike: Increase in the employee's hourly wage
# 26. PerformanceRating: Employee performance evaluation
# 27. RelationshipSatisfaction: The employee's level of satisfaction with their professional relationships
# 28. StandardHours: The employee's standard working hours
# 29. StockOptionLevel: The employee's level of buy-in options for actions
# 30. TotalWorkingYears: The employee's total years of work experience
# 31. TrainingTimesLastYear: The number of times the employee received training last year
# 32. WorkLifeBalance: Balance harmony between an employee's professional and personal lives.
# 33. YearsAtCompany: The number of years the employee has worked for the current company
# 34. YearsInCurrentRole: The number of years the employee has been in their current position
# 35. YearsSinceLastPromotion: The number of years since the employee's last promotion
# 36. YearsWithCurrManager: The number of years the employee has worked with their current manager

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import math
import numpy as np
import scipy.stats as stats
from scipy.stats import binom
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.stats import f_oneway

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Integrated_CA2_Dataset.csv')

# %%
df.shape
print('The dataset original shape is: ', df.shape)
# Out:
# The dataset original shape is:  (1470, 35)

# %% [markdown]
# Using the following code, we can see that we don't have any null values, but we'll still carry out a statistical analysis to determine the values that our variables contain.

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ### Descriptive Statistics

# %% [markdown]
# This function provide us with the descriptive statistics for our dataset. A list of each column statistic in the dataset is the output of this function. Having a thorough understanding of the data being worked on is helpul for identifiyin outliers or missing data.
# In the next table we can see the statistics just from the categorical variables where we observe unique values, the grequency and the top of the class that is more frecuent.
# In the second table analyse the numerical variables for this dataset and the following summary displays the mean, standar deviation, minimum and maximum values and the percentiles of 25, 50 and 75%.

# %%
df.describe(include=object)
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
stat=df.describe()
stat.T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ### Looking at the distribution of Target variable

# %% [markdown]
# As we mentioned since the beggining we have selected to analyse as the variable target **JobSatisfaction** because employee motivation, commitment, and performance are all influenced by their level of job satisfaction, which is a vital factor.
# By observing the values that are contained in our variable target, we can infer that they refer to various types of satisfaction levels, with number 1 denoting a low level of satisfaction, number 2 a medium level of satisfaction, number 3 a high level of satisfaction, and number 4 a very high level of satisfaction.

# %%
df['JobSatisfaction'].unique()
# Out:
# array([4, 2, 3, 1], dtype=int64)

# %%
df['JobSatisfaction'].value_counts()
# Out:
# 4    459
# 3    442
# 1    289
# 2    280
# Name: JobSatisfaction, dtype: int64

# %%
#Bar Plot target variable
target = df.groupby('JobSatisfaction').size()
target.plot(kind='bar',figsize=(4,3),
                 title= 'Job Satisfaction');

# %% [markdown]
# The distribution inside our variable can be seen in the previous graph, and we can infer that it represents the levels of employee satisfaction currently working for the company.

# %% [markdown]
# ### Removing useless columns from the data

# %% [markdown]
# Using the following code, we will examine the values contained within each of our columns while also determining which columns are not required for our analysis.
# In the next step we are going to find the uniques values for each column to understand which column is categorical and wich one is continuous. Typically if the number of unique values are < 20 then the variable is likely to be a category otherwise continuous.

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %% [markdown]
# The observed data are fairly limited and don't amount to many classes, therefore after looking at the values in each of our columns, we can say that there are additional criteria to include as categories. Therefore, we shall move forward with our independent categorical and numerical analyses of them.

# %%
# Categorical data ['Attrition','BusinessTravel', 'Department', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'MaritalStatus', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating','RelationshipSatisfaction', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']

# %%
# Numerical or Continuos data ['Age','DailyRate','DistanceFromHome','HourlyRate','MonthlyIncome','MonthlyRate','TotalWorkingYears','YearsAtCompany']

# %% [markdown]
# Deleting those columns which are not useful in predictive analysis because these variables are directly not important for our analysis since they are not correlated with our target variable and for our analisys.

# %%
uselessColumns = ['EmployeeCount',
       'EmployeeNumber','Over18',
       'StandardHours', 'StockOptionLevel']
df.drop(columns=uselessColumns, axis=1, inplace=True)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PercentSalaryHike  PerformanceRating  \
# 0  Female  ...                 11                  3
# ...

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# - Categorical variables: Bar plot

# %%
def PlotBarCharts(inpData, colsToPlot):
    # Calculating the number of rows and columns needed
    numPlots = len(colsToPlot)
    numRows = (numPlots + 1) // 2  # Round up to the nearest integer
    numCols = 3

    # Generating subplots with two levels
    fig, axes = plt.subplots(nrows=numRows, ncols=numCols, figsize=(30, numRows*8))
    fig.suptitle('Bar charts of: ' + str(colsToPlot))

    # Flattening the subplots array for easier indexing
    axes = axes.flatten()

    for i, colName in enumerate(colsToPlot):
        inpData.groupby(colName).size().plot(kind='bar', ax=axes[i])
        axes[i].set_title(colName, fontsize=30)  
        axes[i].tick_params(axis='both', labelsize=15) 

    # Removing empty subplots
    if numPlots < numRows * numCols:
        for j in range(numPlots, numRows*numCols):
            fig.delaxes(axes[j])

    plt.tight_layout()
    plt.show()

# %%
# Calling the function
PlotBarCharts(df, colsToPlot=['Attrition','BusinessTravel', 'Department', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'MaritalStatus', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating','RelationshipSatisfaction', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager'])

# %% [markdown]
# In the previous graphs, we can see the distribution of our categorical columns, the classes that each one contains, as well as the various frequencies that exist among them. Additionaly we can see that some of them are skewed to the righ such as 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager'. They need to have a correlation analysis done on them for our analysis.

# %% [markdown]
# - Continuous variables: Histogram

# %%
data = df
plt.figure(figsize=(25, 20))

plt.subplot(4, 2, 1)
sns.countplot(x='Age', palette=None, data=data)
plt.xlabel("Age")

plt.subplot(4, 2, 2)
sns.countplot(x='DailyRate', palette=None, data=data)
plt.xlabel("DailyRate")

plt.subplot(4, 2, 3)
sns.countplot(x='DistanceFromHome', palette=None, data=data)
plt.xlabel("DistanceFromHome")

plt.subplot(4, 2, 4)
sns.countplot(x='HourlyRate', palette=None, data=data)
plt.xlabel("HourlyRate")

plt.subplot(4, 2, 5)
sns.countplot(x='MonthlyIncome', palette=None, data=data)
plt.xlabel("MonthlyIncome")

plt.subplot(4, 2, 6)
sns.countplot(x='MonthlyRate', palette=None, data=data)
plt.xlabel("MonthlyRate")

plt.subplot(4, 2, 7)
sns.countplot(x='TotalWorkingYears', palette=None, data=data)
plt.xlabel("TotalWorkingYears")

plt.subplot(4, 2, 8)
sns.countplot(x='YearsAtCompany', palette=None, data=data)
plt.xlabel("YearsAtCompany")

plt.tight_layout()
plt.show()

# %% [markdown]
# The previous graphs for the numerical variables show various distributions of their data, with some of them appearing equally biassed to the right. We will continue with the analysis and use correlation techniques to determine whether they are useful and how they affect us in order to determine what direct relationship our variable target may have.

# %% [markdown]
# - Creating box plots for each continuous predictor against the Target Variable "JobSatisfaction "

# %%
continuousColsList = ['Age','DailyRate','DistanceFromHome','HourlyRate','MonthlyIncome',
                      'MonthlyRate','TotalWorkingYears','YearsAtCompany']
fig, PlotCanvas=plt.subplots(nrows=1,
                             ncols=len(continuousColsList), figsize=(18,5))

for PredictorCol, i in zip(continuousColsList,
                          range(len(continuousColsList))):
    df.boxplot(column=PredictorCol, by='JobSatisfaction', figsize=(5,5),
              vert=True, ax=PlotCanvas[i])

# %% [markdown]
# We can see from the box plots displayed previously that some of them display fictitious values that might correspond to a spike in our data. To deal with these extreme values, we'll first perform a standardisation using the StandarScaler method within our preprocessing for our data set before applying our model because we need all of our characteristics to be on the same scale and not dominate one over the other.

# %% [markdown]
# - To continue with our analysis, it is necessary to change our categorical variables by replacing the classes that include numerical values, and then we will verify with our code ***info()*** that the changes we made were successful.

# %%
# Categorical data ['Attrition','BusinessTravel', 'Department', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'MaritalStatus', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating','RelationshipSatisfaction', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']

# %%
# Checking unique values by attribute non numerical
df['Attrition'].unique(), df["BusinessTravel"].unique(), df["Department"].unique(), df["EducationField"].unique(), df['Gender'].unique(), df["JobRole"].unique(), df["MaritalStatus"].unique(), df["OverTime"].unique()
# Out:
# (array(['Yes', 'No'], dtype=object),
#  array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object),
#  array(['Sales', 'Research & Development', 'Human Resources'], dtype=object),
#  array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#         'Technical Degree', 'Human Resources'], dtype=object),
#  array(['Female', 'Male'], dtype=object),
#  array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#         'Manufacturing Director', 'Healthcare Representative', 'Manager',
#         'Sales Representative', 'Research Director', 'Human Resources'],
#        dtype=object),
#  array(['Single', 'Married', 'Divorced'], dtype=object),
#  array(['Yes', 'No'], dtype=object))

# %%
df['Attrition'].replace('No', 0, inplace = True)
df['Attrition'].replace('Yes', 1, inplace = True)

# %%
df['BusinessTravel'].replace('Travel_Rarely', 0, inplace = True)
df['BusinessTravel'].replace('Travel_Frequently', 1, inplace = True)
df['BusinessTravel'].replace('Non-Travel', 2, inplace = True)

# %%
df['Department'].replace('Sales', 0, inplace = True)
df['Department'].replace('Research & Development', 1, inplace = True)
df['Department'].replace('Human Resources', 2, inplace = True)

# %%
df['EducationField'].replace('Life Sciences', 0, inplace = True)
df['EducationField'].replace('Other', 1, inplace = True)
df['EducationField'].replace('Medical', 2, inplace = True)
df['EducationField'].replace('Marketing', 3, inplace = True)
df['EducationField'].replace('Technical Degree', 4, inplace = True)
df['EducationField'].replace('Human Resources', 5, inplace = True)

# %%
df['Gender'].replace('Female', 0, inplace = True)
df['Gender'].replace('Male', 1, inplace = True)

# %%
df['JobRole'].replace('Sales Executive', 0, inplace = True)
df['JobRole'].replace('Research Scientist', 1, inplace = True)
df['JobRole'].replace('Laboratory Technician', 2, inplace = True)
df['JobRole'].replace('Manufacturing Director', 3, inplace = True)
df['JobRole'].replace('Healthcare Representative', 4, inplace = True)
df['JobRole'].replace('Manager', 5, inplace = True)
df['JobRole'].replace('Sales Representative', 3, inplace = True)
df['JobRole'].replace('Research Director', 4, inplace = True)
df['JobRole'].replace('Human Resources', 5, inplace = True)

# %%
df['MaritalStatus'].replace('Single', 0, inplace = True)
df['MaritalStatus'].replace('Married', 1, inplace = True)
df['MaritalStatus'].replace('Divorced', 2, inplace = True)

# %%
df['OverTime'].replace('No', 0, inplace = True)
df['OverTime'].replace('Yes', 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   int64
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int64
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int64
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   int64
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   int64
# ...

# %% [markdown]
# By examining the IQR values, we can see how the data are dispersed and how they are distributed, and by doing so, we can see how variable the data are.
# The values of the IQR vary widely across different columns, indicating that the caracteristics in the collection of data are dispersed at various levels. In certain columns the intercuartil range is large, suggesting greater data variability, whereas in other columns, the intercuartil range is less, suggesting less dispersion in the data by looking at the IQR values. Those columns with a higher intercuartil range, such as 'MonthlyRate' and 'MontlyIncome' display a significant variation in the values indicating that they may be significant attibutes for analysis.

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3-Q1
IQR.sort_values(ascending=False)
# Out:
# MonthlyRate                 12414.50
# MonthlyIncome                5468.00
# DailyRate                     692.00
# HourlyRate                     35.75
# Age                            13.00
# DistanceFromHome               12.00
# TotalWorkingYears               9.00
# YearsAtCompany                  6.00
# PercentSalaryHike               6.00
# YearsInCurrentRole              5.00
# YearsWithCurrManager            5.00
# YearsSinceLastPromotion         3.00
# NumCompaniesWorked              3.00
# EducationField                  2.00
# JobRole                         2.00
# JobSatisfaction                 2.00
# EnvironmentSatisfaction         2.00
# JobLevel                        2.00
# RelationshipSatisfaction        2.00
# Education                       2.00
# TrainingTimesLastYear           1.00
# BusinessTravel                  1.00
# Department                      1.00
# WorkLifeBalance                 1.00
# JobInvolvement                  1.00
# ...

# %%
IQR.sort_values(ascending=False).plot(kind="bar",  figsize=(8,4))
plt.title("IQR By Attribute");

# %% [markdown]
# The results of the skewness provide us details about the asymmetry of the distributions of the various variables in our data. Some variables show an asymetria to the right, indicating that there are atypical values or a concentration of values at the extreme right of the distribution.
#
# We will proceed to analyse the ones with higher results
#
# - YearsSinceLastPromotion: This suggest that there is a higher concentration of values towards the extreme right of the distribution, which means that the majority of people have gone longer without receiving a promotion.
# - PerformanceRating: This suggest that there is a higher concentration of values in the performance rating, indicating that the majority of employees have a high performance assesment
# - Attrition: This suggest that there is a higher concentration of values towards the extreme right of the distribution, suggesting that a sizeable portion of the workforce has left the company
# - YearsAtCompany: This suggest that there is a higher concentration of values towards the extreme right of the distribution, indicating that the majority of the workforce has worked for the company for a longer period of time

# %%
skew_df = df.skew()
skew_df.sort_values(ascending=False)
# Out:
# YearsSinceLastPromotion     1.984290
# PerformanceRating           1.921883
# Attrition                   1.844366
# YearsAtCompany              1.764529
# BusinessTravel              1.439006
# MonthlyIncome               1.369817
# TotalWorkingYears           1.117172
# NumCompaniesWorked          1.026471
# JobLevel                    1.025401
# OverTime                    0.964489
# DistanceFromHome            0.958118
# YearsInCurrentRole          0.917363
# YearsWithCurrManager        0.833451
# PercentSalaryHike           0.821128
# TrainingTimesLastYear       0.553124
# EducationField              0.487091
# Age                         0.413286
# JobRole                     0.267821
# MaritalStatus               0.152175
# MonthlyRate                 0.018578
# DailyRate                  -0.003519
# HourlyRate                 -0.032311
# Department                 -0.172231
# Education                  -0.289681
# RelationshipSatisfaction   -0.302828
# ...

# %%
skew_df.sort_values(ascending=False).plot(kind="bar",figsize=(8,4))
plt.title("Skewness By Attribute");

# %%
plt.figure(figsize=(20,10))
c = df.corr()
sns.heatmap(c,cmap="Blues",annot=True);

# %% [markdown]
# ### ANOVA test (Categorical Vs Continuous)

# %%
# Categorical data ['Attrition','BusinessTravel', 'Department', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'MaritalStatus', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating','RelationshipSatisfaction', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']

# %%
# Numerical or Continuous data ['Age','DailyRate','DistanceFromHome','HourlyRate','MonthlyIncome','MonthlyRate','TotalWorkingYears','YearsAtCompany']

# %%
# Defining a function to find the statistical relationship with all the categorical variables
def FunctionAnova(inpData, TargetVariable, ContinuousPredictorList):
    # Creating an empty list of final selected predictors
    SelectedPredictors=[]
    
    print('##### ANOVA Results ##### \n')
    for predictor in ContinuousPredictorList:
        CategoryGroupLists=inpData.groupby(TargetVariable)[predictor].apply(list)
        AnovaResults = f_oneway(*CategoryGroupLists)
        
        # If the ANOVA P-Value is <0.05, that means we reject H0
        if (AnovaResults[1] < 0.05):
            print(predictor, 'is correlated with', TargetVariable, '| P-Value:', AnovaResults[1])
            SelectedPredictors.append(predictor)
        else:
            print(predictor, 'is NOT correlated with', TargetVariable, '| P-Value:', AnovaResults[1])
    return(SelectedPredictors)

# %%
# Calling the function to check which continuous variables are correlated with target
continuousVariables = ['Age','DailyRate','DistanceFromHome','HourlyRate','MonthlyIncome','MonthlyRate','TotalWorkingYears','YearsAtCompany']
FunctionAnova(df, 'JobSatisfaction', continuousVariables)
# Out:
# ##### ANOVA Results #####
#
# Age is NOT correlated with JobSatisfaction | P-Value: 0.9844403066163281
# DailyRate is NOT correlated with JobSatisfaction | P-Value: 0.15103920004212745
# DistanceFromHome is NOT correlated with JobSatisfaction | P-Value: 0.9055666234307
# HourlyRate is correlated with JobSatisfaction | P-Value: 0.039040438247272276
# MonthlyIncome is NOT correlated with JobSatisfaction | P-Value: 0.9940001654548951
# MonthlyRate is NOT correlated with JobSatisfaction | P-Value: 0.6731749228252926
# TotalWorkingYears is NOT correlated with JobSatisfaction | P-Value: 0.8427890335746224
# YearsAtCompany is NOT correlated with JobSatisfaction | P-Value: 0.9917528760244054
# ['HourlyRate']

# %% [markdown]
# Based on the findings of the ANOVA analysis, there is a significant correlation between our variable target and HourlyRate. This suggest that it may have an effect on the JobSatisfaction. However there was no significant correlation found between the other predictor variables and job satisfaction. These findings offer crucial information for understanding what factors may affect JobSatisfaction and may be helpful in making decisions regarding human resource management and workplace environment improvement.
# However its vital to note that job satisfaction is a complex concept that can be influenced by variety of factor, both objective and subjective. Although the variables examined did not show a significant correlation in this particular set of data it does not necessarily follow that there is no correlation in other contexts or that other factors are not important for job satisfaction.

# %% [markdown]
# ### Chi-Square Test (Categorical Vs Categorical)

# %%
# Categorical data ['Attrition','BusinessTravel', 'Department', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'MaritalStatus', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating','RelationshipSatisfaction', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']

# %%
# Writing a function to find the correlation of all categorical variables with the Target variable
def FunctionChisq(inpData, TargetVariable, CategoricalVariablesList):
    from scipy.stats import chi2_contingency
    
    # Creating an empty list of final selected predictors
    SelectedPredictors=[]

    for predictor in CategoricalVariablesList:
        CrossTabResult=pd.crosstab(index=inpData[TargetVariable], columns=inpData[predictor])
        ChiSqResult = chi2_contingency(CrossTabResult)
        
        # If the ChiSq P-Value is <0.05, that means we reject H0
        if (ChiSqResult[1] < 0.05):
            print(predictor, 'is correlated with', TargetVariable, '| P-Value:', ChiSqResult[1])
            SelectedPredictors.append(predictor)
        else:
            print(predictor, 'is NOT correlated with', TargetVariable, '| P-Value:', ChiSqResult[1])        
            
    return(SelectedPredictors)

# %%
categoricalVariables = ['Attrition','BusinessTravel', 'Department', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'MaritalStatus', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating','RelationshipSatisfaction', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']

# Calling the function
FunctionChisq(df, 'JobSatisfaction', categoricalVariables)
# Out:
# Attrition is correlated with JobSatisfaction | P-Value: 0.0005563004510387556
# BusinessTravel is NOT correlated with JobSatisfaction | P-Value: 0.5159466426413337
# Department is NOT correlated with JobSatisfaction | P-Value: 0.20189678484148324
# Education is NOT correlated with JobSatisfaction | P-Value: 0.3668860270833084
# EducationField is NOT correlated with JobSatisfaction | P-Value: 0.3634492355330966
# EnvironmentSatisfaction is NOT correlated with JobSatisfaction | P-Value: 0.8056362882487926
# Gender is NOT correlated with JobSatisfaction | P-Value: 0.4667353155281221
# JobInvolvement is NOT correlated with JobSatisfaction | P-Value: 0.5933330853967866
# JobLevel is NOT correlated with JobSatisfaction | P-Value: 0.9027142867098723
# JobRole is NOT correlated with JobSatisfaction | P-Value: 0.5324204430012431
# MaritalStatus is NOT correlated with JobSatisfaction | P-Value: 0.828453949111825
# ...

# %% [markdown]
# Based on the findings we can said that the variable 'Attrition' is significantly correlated with job satisfaction. This can suggest that changes in staff may affect how satisfied the company's employees are with their jobs. Its crucial to go deeper into this relationship and think about approaches to dealing with unemployment and boosting workplace satisfaction.
# Howver, caution should be used when interpreting these results because correlation does not imply causation. To obtain a more thorough understanding of the factors that influence job satisfaction its advised to conduct a deeper analysis, take into account more relevant variables or get more data for better results.

# %% [markdown]
# ### Scaling Data

# %% [markdown]
# As we mentioned before we have some columns that present some fictitious values, so we will proceed to deal with this using a standardisation method named StandarScaler to obtain all our characteristics on the same scale to have a mean of zero and standard deviation of one. As we can see in the table below our results after applying the StandarScaler have changed.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df_ML = df.drop(["JobSatisfaction"], axis=1)
df_ML = scaler.fit_transform(df_ML)
df_ML = pd.DataFrame(df_ML, columns=df.drop(["JobSatisfaction"], axis=1).columns)

# %%
df_ML.head()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0  0.446350   2.280906       -0.590048   0.742527   -1.401512
# 1  1.322365  -0.438422        0.913194  -1.297775    0.493817
# 2  0.008343   2.280906       -0.590048   1.414363    0.493817
# 3 -0.429664  -0.438422        0.913194   1.461466    0.493817
# 4 -1.086676  -0.438422       -0.590048  -0.524295    0.493817
#
#    DistanceFromHome  Education  EducationField  EnvironmentSatisfaction  \
# 0         -1.010909  -0.891688       -1.021863                -0.660531
# 1         -0.147150  -1.868426       -1.021863                 0.254625
# 2         -0.887515  -0.891688       -0.323194                 1.169781
# 3         -0.764121   1.061787       -1.021863                 1.169781
# 4         -0.887515  -1.868426        0.375475                -1.575686
#
#      Gender  ...  PercentSalaryHike  PerformanceRating  \
# 0 -1.224745  ...          -1.150554          -0.426230
# ...

# %% [markdown]
# # PCA vs LDA

# %% [markdown]
# The difference between PCA and LDA steams from their focus. PCA is a non-supervised dimentionality reduction technique that focuses on capturing all of the data's variation, whereas LDA is a supervised technique that seeks to maximise class separation. While LDA is primarily used to improve the clasification capability of models by increasing class separability, PCA is better suited for applications like data visualisation and data compression.

# %% [markdown]
# ### PCA

# %%
df.shape
# Out:
# (1470, 30)

# %%
from sklearn.decomposition import PCA

pca = PCA(0.995).fit(df_ML)
num_components = pca.n_components_

print('Number of Components:', num_components)
# Out:
# Number of Components: 28

# %%
pca = PCA(28)

projected = pca.fit_transform(df_ML)

projected.shape
# Out:
# (1470, 28)

# %%
df_projected = pd.DataFrame(projected)

new_col_names = [f"Z{i+1}" for i in range(28)]
df_projected.columns = new_col_names

# %%
df_projected.head()
# Out:
#          Z1        Z2        Z3        Z4        Z5        Z6        Z7  \
# 0 -0.847470  0.492070 -1.189080  3.368788  0.984249 -1.933229  0.584620
# 1  0.498565 -1.330820  3.083315 -0.473249  0.175244  1.177191 -0.968765
# 2 -2.687090  1.355912 -0.184345  0.923668  1.540814 -0.592510 -0.151332
# 3 -0.893931 -0.409106 -1.162170 -0.400466 -0.082594 -0.351723 -2.020537
# 4 -1.822594  0.999621 -0.840743 -0.742955 -0.112510  0.705744  0.224535
#
#          Z8        Z9       Z10  ...       Z19       Z20       Z21       Z22  \
# 0 -2.930794  0.413645  1.527741  ...  0.566618  1.149323  0.343559 -0.750180
# 1  1.271972  0.330053  1.208314  ... -0.732352  0.450464  1.204311  0.509950
# 2 -0.831939 -0.481221 -0.934526  ...  0.373969  1.381083  0.306015  0.203403
# 3 -0.809886  1.765817  0.951024  ... -0.233305 -0.832298  0.016100  0.363336
# 4  1.021734 -0.440811 -0.604008  ... -1.783286  2.257318  0.419817 -0.882356
#
#         Z23       Z24       Z25       Z26       Z27       Z28
# ...

# %%
df_projected["JobSatisfaction"] = df['JobSatisfaction']

df_projected.head(-5)
# Out:
#             Z1        Z2        Z3        Z4        Z5        Z6        Z7  \
# 0    -0.847470  0.492070 -1.189080  3.368788  0.984249 -1.933229  0.584620
# 1     0.498565 -1.330820  3.083315 -0.473249  0.175244  1.177191 -0.968765
# 2    -2.687090  1.355912 -0.184345  0.923668  1.540814 -0.592510 -0.151332
# 3    -0.893931 -0.409106 -1.162170 -0.400466 -0.082594 -0.351723 -2.020537
# 4    -1.822594  0.999621 -0.840743 -0.742955 -0.112510  0.705744  0.224535
# ...        ...       ...       ...       ...       ...       ...       ...
# 1460 -1.589586 -0.849403 -0.523719  0.093633  0.420701 -0.564741  1.127642
# 1461  0.284737  1.142296 -0.943170  3.558887  1.257257  0.056179 -1.505982
# 1462  3.283081 -2.414560 -1.384344  1.215825  0.326243  0.309676  0.365866
# 1463  0.239487 -0.879442  0.571730 -1.166235  0.348906  0.115464  1.360925
# 1464 -2.118240 -0.401875  0.035103  0.083883 -0.012644  2.025058 -1.542150
#
# ...

# %% [markdown]
# After applying the PCA technique we can observe that our columns were reduced since they went from 30 to 28. Now we will proceed to evaluate the models to see how the accuracy can be affected

# %% [markdown]
# # Model Building and Evaluation

# %% [markdown]
# ## Applying the Logistic Regression model with 10% testing and 90% training using the PCA technique

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from matplotlib import pyplot
from sklearn.model_selection import GridSearchCV

# %%
X = df_projected.drop('JobSatisfaction', axis=1)
y = df_projected['JobSatisfaction']

X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.1, random_state=1)

print(X_train.shape, X_validation.shape, y_train.shape, y_validation.shape)
# Out:
# (1323, 28) (147, 28) (1323,) (147,)

# %%
y_train.value_counts()
# Out:
# 3    406
# 4    403
# 2    260
# 1    254
# Name: JobSatisfaction, dtype: int64

# %%
models = []
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(gamma='auto')))
models.append(('KNN', KNeighborsClassifier()))
models.append(('RFC', RandomForestClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))

# %%
results = []
names = []

for name, model in models:
    kfold = StratifiedKFold(n_splits=20, random_state=1, shuffle=True)

    # Identify the search parameters and their potential values
    param_grid = {}
    if name == 'Logistic Regression':
        param_grid = {'solver': ['liblinear', 'sag', 'saga'],
                      'multi_class': ['ovr', 'multinomial']}
    elif name == 'Random Forest':
        param_grid = {'n_estimators': [100, 200, 500],
                      'max_depth': [None, 5, 10]}
   
    # Making the object. GridSearchCV
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=kfold, scoring='accuracy')

    # Modify the model using GridSearchCV
    grid_search.fit(X_train, y_train)

       # Obtain the best model and the best hyperparameters.
    best_params = grid_search.best_params_
    best_model = grid_search.best_estimator_

    # Execute predictions using the best model
    y_pred = best_model.predict(X_validation)

    # Calculate and store the accuracy.
    accuracy = accuracy_score(y_validation, y_pred)
    results.append(accuracy)
    names.append(name)

    # Print results
    print('\nModel:', name)
    print('Best Parameters:', best_params)
    print('Accuracy:', accuracy)
# Out:
# Model: NB
# Best Parameters: {}
# Accuracy: 0.2857142857142857
#
# Model: SVM
# Best Parameters: {}
# Accuracy: 0.2857142857142857
#
# Model: KNN
# Best Parameters: {}
# Accuracy: 0.3197278911564626
#
# Model: RFC
# Best Parameters: {}
# Accuracy: 0.3129251700680272
#
# Model: CART
# Best Parameters: {}
# Accuracy: 0.29931972789115646
#
# Model: LR
# Best Parameters: {}
# Accuracy: 0.3673469387755102

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score

param_grid = {'solver': ['liblinear', 'sag', 'saga'],
              'multi_class': ['ovr', 'multinomial']}

model = LogisticRegression()

grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)

# Conduct the hyperparameter search
grid_search.fit(X_train, y_train)

# Obtain the best measured hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Obtain the best model that has been trained with the best hyperparameters
best_model = grid_search.best_estimator_

# Making predictions in the whole validation process
y_pred = best_model.predict(X_validation)

# Calculate and display the accuracy and classification report.
print("Accuracy Score: ", accuracy_score(y_validation, y_pred))
print("\nClassification Report:\n", classification_report(y_validation, y_pred))

# Calculate and display the confusion matrix
cm = confusion_matrix(y_validation, y_pred)
sns.heatmap(cm, annot=True)

print("\nConfusion Matrix: "'\n', confusion_matrix(y_validation, y_pred))

# Complete cross-validation using the best model
cross_val_scores = cross_val_score(best_model, X_train, y_train, cv=5)
print("\nCross-Validation Scores:", cross_val_scores)
print("Average Cross-Validation Score:", cross_val_scores.mean())
# Out:
# Best Hyperparameters: {'multi_class': 'ovr', 'solver': 'liblinear'}
# Accuracy Score:  0.3673469387755102
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.60      0.17      0.27        35
#            2       0.17      0.05      0.08        20
#            3       0.29      0.56      0.38        36
#            4       0.44      0.48      0.46        56
#
#     accuracy                           0.37       147
#    macro avg       0.37      0.31      0.30       147
# weighted avg       0.40      0.37      0.34       147
#
#
# Confusion Matrix:
#  [[ 6  2 15 12]
#  [ 1  1  9  9]
#  [ 1  2 20 13]
#  [ 2  1 26 27]]
#
# Cross-Validation Scores: [0.34339623 0.26792453 0.28301887 0.3219697  0.29924242]
# Average Cross-Validation Score: 0.3031103487707262

# %% [markdown]
# ## Applying the Logistic Regression model with 20% testing and 80% training using the PCA technique

# %%
X = df_projected.drop('JobSatisfaction', axis=1)
y = df_projected['JobSatisfaction']

X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.2, random_state=1)

print(X_train.shape, X_validation.shape, y_train.shape, y_validation.shape)
# Out:
# (1176, 28) (294, 28) (1176,) (294,)

# %%
y_train.value_counts()
# Out:
# 4    361
# 3    353
# 2    237
# 1    225
# Name: JobSatisfaction, dtype: int64

# %%
models = []
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(gamma='auto')))
models.append(('KNN', KNeighborsClassifier()))
models.append(('RFC', RandomForestClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))

# %%
results = []
names = []

for name, model in models:
    kfold = StratifiedKFold(n_splits=20, random_state=1, shuffle=True)

    # Identify the search parameters and their potential values
    param_grid = {}
    if name == 'Logistic Regression':
        param_grid = {'solver': ['liblinear', 'sag', 'saga'],
                      'multi_class': ['ovr', 'multinomial']}
    elif name == 'Random Forest':
        param_grid = {'n_estimators': [100, 200, 500],
                      'max_depth': [None, 5, 10]}
   
    # Making the object. GridSearchCV
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=kfold, scoring='accuracy')

    # Modify the model using GridSearchCV
    grid_search.fit(X_train, y_train)

       # Obtain the best model and the best hyperparameters.
    best_params = grid_search.best_params_
    best_model = grid_search.best_estimator_

    # Execute predictions using the best model
    y_pred = best_model.predict(X_validation)

    # Calculate and store the accuracy
    accuracy = accuracy_score(y_validation, y_pred)
    results.append(accuracy)
    names.append(name)

    # Print results
    print('\nModel:', name)
    print('Best Parameters:', best_params)
    print('Accuracy:', accuracy)
# Out:
# Model: NB
# Best Parameters: {}
# Accuracy: 0.2687074829931973
#
# Model: SVM
# Best Parameters: {}
# Accuracy: 0.3129251700680272
#
# Model: KNN
# Best Parameters: {}
# Accuracy: 0.2585034013605442
#
# Model: RFC
# Best Parameters: {}
# Accuracy: 0.282312925170068
#
# Model: CART
# Best Parameters: {}
# Accuracy: 0.2891156462585034
#
# Model: LR
# Best Parameters: {}
# Accuracy: 0.35374149659863946

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score

param_grid = {'solver': ['liblinear', 'sag', 'saga'],
              'multi_class': ['ovr', 'multinomial']}

model = LogisticRegression()

grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)

# Conduct the hyperparameter search
grid_search.fit(X_train, y_train)

# Obtain the best measured hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Obtain the best model that has been trained with the best hyperparameters
best_model = grid_search.best_estimator_

# Making predictions in the whole validation process
y_pred = best_model.predict(X_validation)

# Calculate and display the accuracy and classification report
print("Accuracy Score: ", accuracy_score(y_validation, y_pred))
print("\nClassification Report:\n", classification_report(y_validation, y_pred))

# Calculate and display the confusion matrix
cm = confusion_matrix(y_validation, y_pred)
sns.heatmap(cm, annot=True)

print("\nConfusion Matrix: "'\n', confusion_matrix(y_validation, y_pred))

# Complete cross-validation using the best model
cross_val_scores = cross_val_score(best_model, X_train, y_train, cv=5)
print("\nCross-Validation Scores:", cross_val_scores)
print("Average Cross-Validation Score:", cross_val_scores.mean())
# Out:
# Best Hyperparameters: {'multi_class': 'ovr', 'solver': 'liblinear'}
# Accuracy Score:  0.35374149659863946
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.35      0.12      0.18        64
#            2       0.15      0.07      0.10        43
#            3       0.35      0.45      0.39        89
#            4       0.39      0.54      0.45        98
#
#     accuracy                           0.35       294
#    macro avg       0.31      0.30      0.28       294
# weighted avg       0.33      0.35      0.32       294
#
#
# Confusion Matrix:
#  [[ 8  7 23 26]
#  [ 3  3 15 22]
#  [ 8  5 40 36]
#  [ 4  5 36 53]]
#
# Cross-Validation Scores: [0.27542373 0.27234043 0.2893617  0.29361702 0.31489362]
# Average Cross-Validation Score: 0.2891272989542012

# %% [markdown]
# ### Results and analysis using PCA using 2 splits

# %% [markdown]
# In summary after comparing the results, the second result shows better performance terms of precision and f1-score for all classes, indicating a better classification ability compared to the first result. Additionally the second result also has a slightly lower but more stable average accuracy score in cross validation.
# The precision result has a higher values for all classes compared to the first result, indicating that the model has a higher ability to correctly classify instances in each class.
# The F1 score is higher in the second results indicating that the model has a better balance between precision and recall.
# Furthermore although the average accuracy score of the second result is slightly lower than the first result, its more stable in cross-validation. This means that the performance of the model in the second result is more consistent across different splits of the training and validation data.

# %% [markdown]
# ## LDA

# %% [markdown]
# ## Applying the Logistic Regression model with 10% testing and 90% training using the LDA technique

# %%
from sklearn.datasets import load_wine
import pandas as pd
import numpy as np
np.set_printoptions(precision=4)
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis()

# Setting up the data
y = df["JobSatisfaction"]
X = df.drop("JobSatisfaction", axis=1)

# Apply the LDA reduction
X_lda = lda.fit_transform(X, y)

num_components = X_lda.shape[1]
print('Number of Components:', num_components)
print('Explained variance ratio:', lda.explained_variance_ratio_)
# Out:
# Number of Components: 3
# Explained variance ratio: [0.5634 0.2848 0.1518]

# %%
from sklearn.model_selection import train_test_split

X = df_projected.drop('JobSatisfaction', axis=1)
y = df_projected['JobSatisfaction']

X_train, X_validation, y_train, y_validation = train_test_split(X_lda, y, test_size=0.1, random_state=1)

print(X_train.shape, X_validation.shape, y_train.shape, y_validation.shape)
# Out:
# (1323, 3) (147, 3) (1323,) (147,)

# %%
y_train.value_counts()
# Out:
# 3    406
# 4    403
# 2    260
# 1    254
# Name: JobSatisfaction, dtype: int64

# %%
models = []
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(gamma='auto')))
models.append(('KNN', KNeighborsClassifier()))
models.append(('RFC', RandomForestClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))

# %%
results = []
names = []

for name, model in models:
    kfold = StratifiedKFold(n_splits=20, random_state=1, shuffle=True)

     # Identify the search parameters and their potential values
    param_grid = {}
    if name == 'Logistic Regression':
        param_grid = {'solver': ['liblinear', 'sag', 'saga'],
                      'multi_class': ['ovr', 'multinomial']}
    elif name == 'Random Forest':
        param_grid = {'n_estimators': [100, 200, 500],
                      'max_depth': [None, 5, 10]}
   
    # Making the object. GridSearchCV
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=kfold, scoring='accuracy')

    # Modify the model using GridSearchCV
    grid_search.fit(X_train, y_train)

        # Obtain the best model and the best hyperparameters
    best_params = grid_search.best_params_
    best_model = grid_search.best_estimator_

    # Execute predictions using the best model
    y_pred = best_model.predict(X_validation)

    # Calculate and store the accuracy.
    accuracy = accuracy_score(y_validation, y_pred)
    results.append(accuracy)
    names.append(name)

    # Print results
    print('\nModel:', name)
    print('Best Parameters:', best_params)
    print('Accuracy:', accuracy)
# Out:
# Model: NB
# Best Parameters: {}
# Accuracy: 0.3673469387755102
#
# Model: SVM
# Best Parameters: {}
# Accuracy: 0.3877551020408163
#
# Model: KNN
# Best Parameters: {}
# Accuracy: 0.272108843537415
#
# Model: RFC
# Best Parameters: {}
# Accuracy: 0.32653061224489793
#
# Model: CART
# Best Parameters: {}
# Accuracy: 0.23809523809523808
#
# Model: LR
# Best Parameters: {}
# Accuracy: 0.41496598639455784

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score

param_grid = {'solver': ['liblinear', 'sag', 'saga'],
              'multi_class': ['ovr', 'multinomial']}

model = LogisticRegression()

grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)

# Conduct the hyperparameter search
grid_search.fit(X_train, y_train)

# Obtain the best measured hyperparameters.
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Obtain the best model that has been trained with the best hyperparameters
best_model = grid_search.best_estimator_

# Making predictions in the whole validation process
y_pred = best_model.predict(X_validation)

# Calculate and display the accuracy and classification report
print("Accuracy Score: ", accuracy_score(y_validation, y_pred))
print("\nClassification Report:\n", classification_report(y_validation, y_pred))

# Calculate and display the confusion matrix
cm = confusion_matrix(y_validation, y_pred)
sns.heatmap(cm, annot=True)

print("\nConfusion Matrix: "'\n', confusion_matrix(y_validation, y_pred))

# Complete cross-validation using the best model
cross_val_scores = cross_val_score(best_model, X_train, y_train, cv=5)
print("\nCross-Validation Scores:", cross_val_scores)
print("Average Cross-Validation Score:", cross_val_scores.mean())
# Out:
# Best Hyperparameters: {'multi_class': 'multinomial', 'solver': 'sag'}
# Accuracy Score:  0.4217687074829932
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.64      0.26      0.37        35
#            2       0.29      0.10      0.15        20
#            3       0.31      0.58      0.41        36
#            4       0.51      0.54      0.52        56
#
#     accuracy                           0.42       147
#    macro avg       0.44      0.37      0.36       147
# weighted avg       0.46      0.42      0.41       147
#
#
# Confusion Matrix:
#  [[ 9  1 13 12]
#  [ 1  2 10  7]
#  [ 2  3 21 10]
#  [ 2  1 23 30]]
#
# Cross-Validation Scores: [0.3698 0.317  0.3472 0.3523 0.3826]
# Average Cross-Validation Score: 0.35376214979988563

# %% [markdown]
# ## Applying the Logistic Regression model with 20% testing and 80% training using the LDA technique

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis()

# Setting up the data
y = df["JobSatisfaction"]
X = df.drop("JobSatisfaction", axis=1)

# Apply the LDA reduction
X_lda = lda.fit_transform(X, y)

num_components = X_lda.shape[1]
print('Number of Components:', num_components)
print('Explained variance ratio:', lda.explained_variance_ratio_)
# Out:
# Number of Components: 3
# Explained variance ratio: [0.5634 0.2848 0.1518]

# %%
from sklearn.model_selection import train_test_split

X = df_projected.drop('JobSatisfaction', axis=1)
y = df_projected['JobSatisfaction']

X_train, X_validation, y_train, y_validation = train_test_split(X_lda, y, test_size=0.2, random_state=1)

print(X_train.shape, X_validation.shape, y_train.shape, y_validation.shape)
# Out:
# (1176, 3) (294, 3) (1176,) (294,)

# %%
y_train.value_counts()
# Out:
# 4    361
# 3    353
# 2    237
# 1    225
# Name: JobSatisfaction, dtype: int64

# %%
models = []
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(gamma='auto')))
models.append(('KNN', KNeighborsClassifier()))
models.append(('RFC', RandomForestClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))

# %%
results = []
names = []

for name, model in models:
    kfold = StratifiedKFold(n_splits=20, random_state=1, shuffle=True)

    # Identify the search parameters and their potential values
    param_grid = {}
    if name == 'Logistic Regression':
        param_grid = {'solver': ['liblinear', 'sag', 'saga'],
                      'multi_class': ['ovr', 'multinomial']}
    elif name == 'Random Forest':
        param_grid = {'n_estimators': [100, 200, 500],
                      'max_depth': [None, 5, 10]}
   
    # Making the object. GridSearchCV
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=kfold, scoring='accuracy')

    # Modify the model using GridSearchCV
    grid_search.fit(X_train, y_train)

        # Obtain the best model and the best hyperparameters
    best_params = grid_search.best_params_
    best_model = grid_search.best_estimator_

    # Execute predictions using the best model
    y_pred = best_model.predict(X_validation)

    # Calculate and store the accuracy.
    accuracy = accuracy_score(y_validation, y_pred)
    results.append(accuracy)
    names.append(name)

    # Print results
    print('\nModel:', name)
    print('Best Parameters:', best_params)
    print('Accuracy:', accuracy)
# Out:
# Model: NB
# Best Parameters: {}
# Accuracy: 0.37755102040816324
#
# Model: SVM
# Best Parameters: {}
# Accuracy: 0.3741496598639456
#
# Model: KNN
# Best Parameters: {}
# Accuracy: 0.24149659863945577
#
# Model: RFC
# Best Parameters: {}
# Accuracy: 0.29591836734693877
#
# Model: CART
# Best Parameters: {}
# Accuracy: 0.30612244897959184
#
# Model: LR
# Best Parameters: {}
# Accuracy: 0.40476190476190477

# %%
from sklearn.model_selection import GridSearchCV, cross_val_score

param_grid = {'solver': ['liblinear', 'sag', 'saga'],
              'multi_class': ['ovr', 'multinomial']}

model = LogisticRegression()

grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)

# Conduct the hyperparameter search
grid_search.fit(X_train, y_train)

# Obtain the best measured hyperparameters.
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Obtain the best model that has been trained with the best hyperparameters
best_model = grid_search.best_estimator_

# Making predictions in the whole validation process
y_pred = best_model.predict(X_validation)

# Calculate and display the accuracy and classification report
print("Accuracy Score: ", accuracy_score(y_validation, y_pred))
print("\nClassification Report:\n", classification_report(y_validation, y_pred))

# Calculate and display the confusion matrix
cm = confusion_matrix(y_validation, y_pred)
sns.heatmap(cm, annot=True)

print("\nConfusion Matrix: "'\n', confusion_matrix(y_validation, y_pred))

# Complete cross-validation using the best model
cross_val_scores = cross_val_score(best_model, X_train, y_train, cv=5)
print("\nCross-Validation Scores:", cross_val_scores)
print("Average Cross-Validation Score:", cross_val_scores.mean())
# Out:
# Best Hyperparameters: {'multi_class': 'multinomial', 'solver': 'sag'}
# Accuracy Score:  0.40476190476190477
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.52      0.22      0.31        64
#            2       0.21      0.07      0.11        43
#            3       0.39      0.49      0.43        89
#            4       0.42      0.59      0.49        98
#
#     accuracy                           0.40       294
#    macro avg       0.38      0.34      0.33       294
# weighted avg       0.40      0.40      0.38       294
#
#
# Confusion Matrix:
#  [[14  2 18 30]
#  [ 3  3 19 18]
#  [ 6  6 44 33]
#  [ 4  3 33 58]]
#
# Cross-Validation Scores: [0.322  0.3106 0.3447 0.3532 0.3745]
# Average Cross-Validation Score: 0.341002524341868

# %% [markdown]
# ### Results and analysis using LDA using 2 splits

# %% [markdown]
# After comparing the two results we can conclude that the first result appears to show a better performance in predicting the level of job satisfaction based on the provided metrics.
# The acuracy is higher than the second result, which indicates that has a higher overall accuracy in predicting job satisfaction levels.
# The precision, recall and F1-score values for each class are generally higher compared to the second result. This suggest that the model in the first result has a better ability to classify instances correctly across all satisfaction levels.

# %% [markdown]
# ### Results and analysis comparing the best results from PCA and LDA

# %% [markdown]
# After comparing the models with bests results using PCA (20% testing, 80% training) and LDA (10% testing, 90% training) we can say the results from the model using LDA demostrates better perfomance compared with the one using PCA.
#
# Using the one with LDA we observe higher precision, recall and f1-score for all classes. This indicates a better classification capability in predicting levels of job satisfaction.
# Furthermore has a higher average accuracy score in cross-validation. This suggests that the LDA based model is more consistent in its performance when generalizing to new data.

# %% [markdown]
# # Conclusion

# %% [markdown]
# - In the context of predicting job satisfaction levels, LDA seems to be more effective than PCA. By considering the class information, LDA can better separate the different levels of satisfaction, leading to improved classification performance. On the other hand, PCA does not take into account the class labels and may not capture the specific variations related to job satisfaction. Therefore based on the higher performance metrics and better stability in cross-validation, its recommended to use LDA soince can provide more accurate and reliable predictions in this particular case.
#
# - If we would like to have a deeper analysis to get better results we would recomend to the company to provide more information related with the employees since our data its too short and we did not get higher correlation between our variable target and the predictic variables

# %% [markdown]
# # Reference List

# %% [markdown]
# Brownlee, J. (2020). Linear Discriminant Analysis for Dimensionality Reduction in Python. [online] Machine Learning Mastery. Available at: https://machinelearningmastery.com/linear-discriminant-analysis-for-dimensionality-reduction-in-python/.
#
# Rosebrock, A. (2021). Grid search hyperparameter tuning with scikit-learn ( GridSearchCV ). [online] PyImageSearch. Available at: https://pyimagesearch.com/2021/05/24/grid-search-hyperparameter-tuning-with-scikit-learn-gridsearchcv/ [Accessed 28 May 2023].
#
# SciKit-Learn (2009). 3.1. Cross-validation: evaluating estimator performance — scikit-learn 0.21.3 documentation. [online] Scikit-learn.org. Available at: https://scikit-learn.org/stable/modules/cross_validation.html.
#
# docs.scipy.org. (n.d.). scipy.stats.ttest_rel — SciPy v1.10.0 Manual. [online] Available at: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_rel.html.
#
# Dino, L. (2022). One-sample chi-square test in Python. [online] Medium. Available at: https://medium.com/@24littledino/one-sample-chi-square-test-in-python-bcd67ced76df.
